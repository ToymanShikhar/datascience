# %% [markdown]
# # Pandas

# %%
# !pip3 install pandas

# %%
import numpy as np
import pandas as pd

# %%
user_data = {
    'Physics': np.random.randint(2,100,20),
    'Chemistry': np.random.randint(5,100,20),
    'Maths': np.random.randint(1,100,20)
}

# %%
df = pd.DataFrame(user_data)

# %%
df
# Out:
#     Physics  Chemistry  Maths
# 0        58         45     88
# 1         2         20     94
# 2        20         42      8
# 3        87         32     23
# 4        47         54     44
# 5        34         53     81
# 6        62         10     92
# 7        37         26     70
# 8        19         26     94
# 9        39         87     66
# 10       43         47      9
# 11       69         94     76
# 12       84         38     98
# 13       85         12     29
# 14       85         85     32
# 15        3         41     60
# 16       17         91     14
# 17       69         62     79
# 18       95         42     37
# 19       57         62     95

# %%
df.head(n=10)
# Out:
#    Physics  Chemistry  Maths
# 0       58         45     88
# 1        2         20     94
# 2       20         42      8
# 3       87         32     23
# 4       47         54     44
# 5       34         53     81
# 6       62         10     92
# 7       37         26     70
# 8       19         26     94
# 9       39         87     66

# %%
print(df.columns)
# Out:
# Index(['Physics', 'Chemistry', 'Maths'], dtype='object')

# %%
df.to_csv('marks.csv')

# %%
my_data = pd.read_csv('marks.csv')

# %%
my_data
# Out:
#     Unnamed: 0  Physics  Chemistry  Maths
# 0            0       58         45     88
# 1            1        2         20     94
# 2            2       20         42      8
# 3            3       87         32     23
# 4            4       47         54     44
# 5            5       34         53     81
# 6            6       62         10     92
# 7            7       37         26     70
# 8            8       19         26     94
# 9            9       39         87     66
# 10          10       43         47      9
# 11          11       69         94     76
# 12          12       84         38     98
# 13          13       85         12     29
# 14          14       85         85     32
# 15          15        3         41     60
# 16          16       17         91     14
# 17          17       69         62     79
# 18          18       95         42     37
# 19          19       57         62     95

# %%
my_data = my_data.drop(columns='Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-cdc815341004> in <module>
# ----> 1 my_data = my_data.drop(columns='Unnamed: 0')
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4150         for axis, labels in axes.items():
#    4151             if labels is not None:
# -> 4152                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4153
#    4154         if inplace:
#
# ...

# %%
print(my_data)
# Out:
#     Physics  Chemistry  Maths
# 0        58         45     88
# 1         2         20     94
# 2        20         42      8
# 3        87         32     23
# 4        47         54     44
# 5        34         53     81
# 6        62         10     92
# 7        37         26     70
# 8        19         26     94
# 9        39         87     66
# 10       43         47      9
# 11       69         94     76
# 12       84         38     98
# 13       85         12     29
# 14       85         85     32
# 15        3         41     60
# 16       17         91     14
# 17       69         62     79
# 18       95         42     37
# 19       57         62     95

# %%
df.describe()
# Out:
#          Physics  Chemistry      Maths
# count  20.000000  20.000000  20.000000
# mean   50.600000  48.450000  59.450000
# std    29.054214  25.425795  31.868934
# min     2.000000  10.000000   8.000000
# 25%    30.500000  30.500000  31.250000
# 50%    52.000000  43.500000  68.000000
# 75%    72.750000  62.000000  89.000000
# max    95.000000  94.000000  98.000000

# %%
idx = [df.columns.get_loc('Physics')]
df.iloc[:10,idx]
# Out:
#    Physics
# 0       58
# 1        2
# 2       20
# 3       87
# 4       47
# 5       34
# 6       62
# 7       37
# 8       19
# 9       39

# %%
df.sort_values(by=['Maths','Chemistry'], ascending=True)
# Out:
#     Physics  Chemistry  Maths
# 2        20         42      8
# 10       43         47      9
# 16       17         91     14
# 3        87         32     23
# 13       85         12     29
# 14       85         85     32
# 18       95         42     37
# 4        47         54     44
# 15        3         41     60
# 9        39         87     66
# 7        37         26     70
# 11       69         94     76
# 17       69         62     79
# 5        34         53     81
# 0        58         45     88
# 6        62         10     92
# 1         2         20     94
# 8        19         26     94
# 19       57         62     95
# 12       84         38     98

# %%
df
# Out:
#     Physics  Chemistry  Maths
# 0        58         45     88
# 1         2         20     94
# 2        20         42      8
# 3        87         32     23
# 4        47         54     44
# 5        34         53     81
# 6        62         10     92
# 7        37         26     70
# 8        19         26     94
# 9        39         87     66
# 10       43         47      9
# 11       69         94     76
# 12       84         38     98
# 13       85         12     29
# 14       85         85     32
# 15        3         41     60
# 16       17         91     14
# 17       69         62     79
# 18       95         42     37
# 19       57         62     95

# %%
df_array = df.values
df.shape
# Out:
# (20, 3)

# %%
print(df_array)
# Out:
# [[58 45 88]
#  [ 2 20 94]
#  [20 42  8]
#  [87 32 23]
#  [47 54 44]
#  [34 53 81]
#  [62 10 92]
#  [37 26 70]
#  [19 26 94]
#  [39 87 66]
#  [43 47  9]
#  [69 94 76]
#  [84 38 98]
#  [85 12 29]
#  [85 85 32]
#  [ 3 41 60]
#  [17 91 14]
#  [69 62 79]
#  [95 42 37]
#  [57 62 95]]

# %%
df_array.shape
# Out:
# (20, 3)

# %%
new_df = pd.DataFrame(df_array,columns=['MarksA','MarksB','MarksC'])

# %%
new_df
# Out:
#     MarksA  MarksB  MarksC
# 0       58      45      88
# 1        2      20      94
# 2       20      42       8
# 3       87      32      23
# 4       47      54      44
# 5       34      53      81
# 6       62      10      92
# 7       37      26      70
# 8       19      26      94
# 9       39      87      66
# 10      43      47       9
# 11      69      94      76
# 12      84      38      98
# 13      85      12      29
# 14      85      85      32
# 15       3      41      60
# 16      17      91      14
# 17      69      62      79
# 18      95      42      37
# 19      57      62      95

# %%
new_df.to_csv('Marks.csv')
